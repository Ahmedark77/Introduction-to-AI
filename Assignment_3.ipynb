# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmedark77/Introduction-to-AI/blob/feature-branch/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Library Management System

# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import pandas as pd
import sqlite3
import requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)

# %%
# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")

# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]
# TODO: Add two more books to the list

books.append("Machine Learning Basics")
books.append("Web Development with Python")

print("Updated book list:", books)
# Out:
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True
# Updated book list: ['Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning Basics', 'Web Development with Python']

# %%
# 3. Loops and range()
print("\nAvailable books:")
# TODO: Use a for loop and range() to print books with their indices
for i in range(len(books)):
    print(f"{i}: {books[i]}")
# Out:
# Available books:
# 0: Python Basics
# 1: Advanced Python
# 2: Data Science with Python
# 3: Machine Learning Basics
# 4: Web Development with Python

# %%
# 4. User Input
new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Enter a new book title: Python for everyone
# Updated book list: ['Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning Basics', 'Web Development with Python', 'Python for everyone']

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    # TODO: Check if the book is in the list and return True if available, False otherwise
    if book_name in books:
        return True
    else:
        return False
# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %%
# 6. File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# TODO: Implement a function to read books from a file
def read_books_from_file(filename):
    books_list = []
    try:
        with open(filename, 'r') as f:
            for line in f:
                books_list.append(line.strip())
        return books_list
    except FileNotFoundError:
        print(f"File {filename} not found.")
        return []

# Test file I/O
save_books_to_file("books.txt")
# !cat books.txt  # Display file contents in Colab

# Test read function
print("\nBooks read from file:", read_books_from_file("books.txt"))
# Out:
# Python Basics
# Advanced Python
# Data Science with Python
# Machine Learning Basics
# Web Development with Python
#
# Books read from file: ['Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning Basics', 'Web Development with Python']

# %%
# 7. Pickle for serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# TODO: Implement a function to load books using pickle
def load_books_pickle(filename):
    try:
        with open(filename, 'rb') as f:
            return pickle.load(f)
    except FileNotFoundError:
        print(f"File {filename} not found.")
        return []
    except:
        print("Error loading pickle file.")
        return []

# Test pickle functions
save_books_pickle("books.pkl")
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning Basics', 'Web Development with Python', 'Python for everyone']

# %%
# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# TODO: Implement a function to add a book to the SQLite database
def add_book_to_db(title, quantity):
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute("INSERT INTO books (title, quantity) VALUES (?, ?)", (title, quantity))
    conn.commit()
    conn.close()
    print(f"Added '{title}' with quantity {quantity} to database.")

# Test database functions
create_books_table()
add_book_to_db("Python for Beginners", 10)
# Out:
# Added 'Python for Beginners' with quantity 10 to database.

# %%
# 9. Web API Interaction (GitHub API)
import requests
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)
    data = response.json()
    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'Python']
#
# Library Management System operations completed.
